# %%
import pandas as pd
import numpy as np

# %%
file_to_load = 'C:/Users/erica/Desktop/School/Git/Amazon_Vine_Analysis/vine_table.csv'
vine_df = pd.read_csv(file_to_load, sep = ';')
vine_df.head()
# Out:
#         review_id  star_rating  helpful_votes  total_votes vine  \
# 0   RTIS3L2M1F5SM            5              0            0    N
# 1   R1ZV7R40OLHKD            5              0            0    N
# 2  R3BH071QLH8QMC            1              0            1    N
# 3  R127K9NTSXA2YH            3              0            0    N
# 4  R32ZWUXDJPW27Q            4              0            0    N
#
#   verified_purchase
# 0                 Y
# 1                 Y
# 2                 Y
# 3                 Y
# 4                 Y

# %%
vine_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1785997 entries, 0 to 1785996
# Data columns (total 6 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   review_id          object
#  1   star_rating        int64
#  2   helpful_votes      int64
#  3   total_votes        int64
#  4   vine               object
#  5   verified_purchase  object
# dtypes: int64(3), object(3)
# memory usage: 81.8+ MB

# %%
filtered_vine_df = (vine_df.loc[(vine_df['total_votes']>=20),['review_id','star_rating','helpful_votes','total_votes','vine','verified_purchase']])
filtered_vine_df.head(20)
# Out:
#            review_id  star_rating  helpful_votes  total_votes vine  \
# 55     R4PKAZRQJJX14            1             21           34    N
# 74    R2CI0Y288CC7E2            1             21           35    N
# 209   R127WEQY2FM1T3            1            147          175    N
# 289   R3EZ0EPYLDA34S            1             14           31    N
# 483   R2FJ94555FZH32            2             55           60    N
# 537   R1U3AR67RE273L            1             51           65    N
# 670   R3PZOXA5X1U8KW            4             31           36    N
# 1359   R6KTC1OPIOIIG            2             19           34    N
# 1402  R36O341WWXXKNP            5             28           31    N
# 1450  R3GSK9MM8DNOYI            1              4           32    N
# 1587  R10LZVBLQHBVJ0            2            151          198    N
# 1788  R1VR5GLGY1GE7N            1             49           51    N
# 1845  R3GUUC6NT4QMCL            1              5           36    N
# ...

# %%
helpful_votes =(filtered_vine_df.loc[(filtered_vine_df['helpful_votes']/filtered_vine_df['total_votes']>=.5),['review_id','star_rating','helpful_votes','total_votes','vine','verified_purchase']])
helpful_votes.head(20)
# Out:
#            review_id  star_rating  helpful_votes  total_votes vine  \
# 55     R4PKAZRQJJX14            1             21           34    N
# 74    R2CI0Y288CC7E2            1             21           35    N
# 209   R127WEQY2FM1T3            1            147          175    N
# 483   R2FJ94555FZH32            2             55           60    N
# 537   R1U3AR67RE273L            1             51           65    N
# 670   R3PZOXA5X1U8KW            4             31           36    N
# 1359   R6KTC1OPIOIIG            2             19           34    N
# 1402  R36O341WWXXKNP            5             28           31    N
# 1587  R10LZVBLQHBVJ0            2            151          198    N
# 1788  R1VR5GLGY1GE7N            1             49           51    N
# 2451  R2OWDAR0EDEPTF            1             23           28    N
# 2507  R29BOS5HMAY1LO            5             88          110    N
# 2645   R8WD0136CETA7            2             99          119    N
# ...

# %%
vine_votes_Y = (helpful_votes.loc[(helpful_votes['vine']=='Y'),['review_id','star_rating','helpful_votes','total_votes','vine','verified_purchase']])
vine_votes_Y.head(20)
# Out:
#              review_id  star_rating  helpful_votes  total_votes vine  \
# 32611   R3KKUSGFZWSUIY            5             56           63    Y
# 33112   R10FO5UKKVZBK2            3             23           23    Y
# 69680    RM4KSGEOR7MU1            5             19           24    Y
# 155361   RG7VRMYLEXD23            4             22           26    Y
# 239327  R11O4YSCPSNL6L            3             20           26    Y
# 335897  R286MFBAJ8NPD6            5             46           51    Y
# 364816  R1JRR530H4COA2            5             22           28    Y
# 367440   RQ5WD90PUNBU9            5             21           24    Y
# 376235  R12648VHCQWUV9            4             21           28    Y
# 381565  R3KAW29CJ8L6DQ            5             17           20    Y
# 416467  R1OWK33OPI45KT            5             55           58    Y
# 417894  R2UP7VTED8O425            5             35           41    Y
# 441172  R3N4QAXTQCA1ED            5             18           20    Y
# ...

# %%
vine_votes_N = (helpful_votes.loc[(helpful_votes['vine']=='N'),['review_id','star_rating','helpful_votes','total_votes','vine','verified_purchase']])
vine_votes_N.head(20)
# Out:
#            review_id  star_rating  helpful_votes  total_votes vine  \
# 55     R4PKAZRQJJX14            1             21           34    N
# 74    R2CI0Y288CC7E2            1             21           35    N
# 209   R127WEQY2FM1T3            1            147          175    N
# 483   R2FJ94555FZH32            2             55           60    N
# 537   R1U3AR67RE273L            1             51           65    N
# 670   R3PZOXA5X1U8KW            4             31           36    N
# 1359   R6KTC1OPIOIIG            2             19           34    N
# 1402  R36O341WWXXKNP            5             28           31    N
# 1587  R10LZVBLQHBVJ0            2            151          198    N
# 1788  R1VR5GLGY1GE7N            1             49           51    N
# 2451  R2OWDAR0EDEPTF            1             23           28    N
# 2507  R29BOS5HMAY1LO            5             88          110    N
# 2645   R8WD0136CETA7            2             99          119    N
# ...

# %%
total_reviews = len(vine_df.review_id)
total_reviews
# Out:
# 1785997

# %%
five_star_reviews = len(vine_df[(vine_df['star_rating']==5)])
five_star_reviews
# Out:
# 1026924

# %%
paid_five_star_count = len(vine_df[(vine_df['star_rating']==5)&(vine_df['vine']=='Y')])
unpaid_five_star_count = len(vine_df[(vine_df['star_rating']==5)&(vine_df['vine']=='N')])

# %%
paid_five_star_count
# Out:
# 1607

# %%
unpaid_five_star_count
# Out:
# 1025317

# %%
paid_five_stars = round(((paid_five_star/five_star_reviews)*100),2)
paid_five_star_percent_vs_total_five_star =(f'{paid_five_stars}%')
paid_five_star_percent_vs_total_five_star
# Out:
# '0.16%'

# %%
unpaid_five_stars = round(((unpaid_five_star/five_star_reviews)*100),2)
unpaid_five_star_percent_vs_total_five_star =(f'{unpaid_five_stars}%')
unpaid_five_star_percent_vs_total_five_star
# Out:
# '99.84%'

# %%
five_star_vs_total = round(((five_star_reviews/total_reviews)*100),2)
five_star_vs_total_percent = (f'{five_star_vs_total}%')
five_star_vs_total_percent
# Out:
# '57.5%'

# %%
paid_five_stars_vs_total = round(((paid_five_star_count/total_reviews)*100),2)
paid_five_stars_vs_total_percent = (f'{paid_five_stars_vs_total}%')
paid_five_stars_vs_total_percent
# Out:
# '0.09%'

# %%
unpaid_five_stars_vs_total = round(((unpaid_five_star_count/total_reviews)*100),2)
unpaid_five_stars_vs_total_percent = (f'{unpaid_five_stars_vs_total}%')
unpaid_five_stars_vs_total_percent
# Out:
# '57.41%'

# %%
vine_votes_count = len(vine_df[(vine_df['vine']=='Y')])
vine_votes_count
# Out:
# 4291

# %%
non_vine_votes_count = len(vine_df[(vine_df['vine']=='N')])
non_vine_votes_count
# Out:
# 1781706

# %%
vine_vs_total = round(((vine_votes_count/total_reviews)*100),2)
vine_vs_total_percent = (f'{vine_vs_total}%')
vine_vs_total_percent
# Out:
# '0.24%'

# %%
paid_five_star_vs_total_vine = round(((paid_five_star_count/vine_votes_count)*100),2)
paid_five_star_vs_total_vine_percent =(f'{paid_five_star_vs_total_vine}%')
paid_five_star_vs_total_vine_percent
# Out:
# '37.45%'

# %%
# Out:
# '23894.59%'
